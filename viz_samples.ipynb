# %%
from generate_samples import generate_readings

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
sys.path.append("./forward_model/")
import stacklineplot

# %%
num_samples = 10

# %%
samples = generate_readings("-l", num_samples)
# Out:
# map location cpu
# d_filename ./ProgressiveGAN/EEG-GAN/eeggan/examples/conv_lin/discriminator-l.pt

# %%
samples.shape
# Out:
# (10, 768)

# %%
num_show = num_samples

# %%
stacklineplot.stackplot(samples,seconds=678/300, ylabels=list(range(num_show)), yscale=.3)
