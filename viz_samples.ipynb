# %%
from generate_samples import generate_readings

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

# %%
sys.path.append("./forward_model/")
import stacklineplot

# %%
num_samples = 16

# %%
# size = "s"
size = "m"
# size = "l"

# %%
samples = generate_readings("-" + size, num_samples)
# Out:
# map location cpu
# d_filename ./ProgressiveGAN/EEG-GAN/eeggan/examples/conv_lin/discriminator-m.pt
# z_vars_sum -31.6293

# %%
num_show = num_samples
stacklineplot.stackplot(samples,seconds=678/300, ylabels=list(range(num_show)), yscale=1)
